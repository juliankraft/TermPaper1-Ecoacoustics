# %%
# loading libraries
import yaml
import os
import pandas as pd
import numpy as np
from typing import Callable

# %%
yaml.SafeLoader.add_constructor(
    'tag:yaml.org,2002:python/object:argparse.Namespace', 
    yaml.SafeLoader.construct_mapping)

class RunEval:
    """
    Class to evaluate a hyper parameter tuning run.

    """
    def __init__(
            self, 
            run_path: str):
        
        """
        run_path: Path to the run folder containing the models.
        """
        self.run_path = run_path
        self.model_paths = self.get_model_paths()

    def get_model_paths(self):
        labels = [name for name in os.listdir(self.run_path) if os.path.isdir(os.path.join(self.run_path, name))]
        paths = [run_path + label for label in labels]
        filtered_paths = [path for path in paths if not path.endswith('/evaluation')]
        return filtered_paths
    
    def get_model_data(self, data_type: str, eval_subset: list = ["test"]):
        """
        data_type:Type of data to be extracted. Options are: ["metrics", "predictions", "model_info"]
        eval_subset:List of data sets to be extracted. Options are: ["train", "validation", "test"]
        """


        if data_type == 'metrics':
            
            def model_data(model_path):
                path = f'{model_path}/metrics.csv'
                metrics = pd.read_csv(path)

                return metrics


        elif data_type == 'predictions':

            def model_data(model_path, eval_subset=eval_subset):
                for data_set in eval_subset:
                    if data_set not in ['train', 'validation', 'test']:
                        raise ValueError(f'{data_set} is not a valid data set. Please choose from: ["train", "validation", "test"]')

                path = f'{model_path}/predictions.csv'
                data = pd.read_csv(path)

                filtered_data = data[data['data_set'].isin(eval_subset)]

                return filtered_data
            
        elif data_type == 'model_info':
            
            def model_data(model_path):

                path = f'{model_path}/all_parameters.yaml'

                with open(path, 'r') as file:
                    model_info = yaml.safe_load(file)
                
                if model_info['n_mels'] is None:
                    model_info['transform'] = 'Spec'
                else:
                    model_info['transform'] = 'MelSpec'

                return model_info
        
        else:
            raise ValueError(f'{type} is not a valid data type. Please choose from: ["metrics", "predictions", "model_info"]')
        
        data = []

        for model_path in self.model_paths:
            data.append(model_data(model_path))
        
        return data
    
    def get_metrics(self, function: Callable[[list, list], list], eval_subset: list = ["test"]):
        """
        function: Function to be applied to the metrics. The function should take y_true and y_pred as inputs and return a list of metrics.
        eval_subset:List of data sets to be extracted. Options are: ["train", "validation", "test"]

        Example:
        self.get_metrics(lambda x, y: [np.mean(x == y)], eval_subset=["test"])
        """
        
        metrics = []

        run_data = self.get_model_data('predictions', eval_subset=eval_subset)

        for data in run_data:
            metric = function(data['class_ID'], data['class_ID_pred'])
            metrics.append(metric)


        return metrics

    def get_keys(self, data_type: str):
        """
        Datatype: Options are: ["metrics", "predictions", "model_info"]
        """
        
        data = self.get_model_data(data_type)
        keys = data[0].keys()
        
        return keys

# %%
run_path = "../logs/main_run/"

run_eval = RunEval(run_path)

# %%
run_eval.get_model_data('metrics')
# Out:
# [       epoch   step  train_acc_epoch  train_acc_step  train_loss_epoch  \
#  0          0      0              NaN        0.100000               NaN
#  1          0      1              NaN        0.300000               NaN
#  2          0      2              NaN        0.000000               NaN
#  3          0      3              NaN        0.100000               NaN
#  4          0      4              NaN        0.000000               NaN
#  ...      ...    ...              ...             ...               ...
#  31160   1354  28452              NaN        0.700000               NaN
#  31161   1354  28453              NaN        0.300000               NaN
#  31162   1354  28454              NaN        0.833333               NaN
#  31163   1354  28454              NaN             NaN               NaN
#  31164   1354  28454         0.601942             NaN          0.475445
#
#         train_loss_step   val_acc  val_loss
#  0             0.347015       NaN       NaN
#  1             0.796305       NaN       NaN
#  2             0.401215       NaN       NaN
#  3             0.793166       NaN       NaN
#  4             0.497443       NaN       NaN
#  ...                ...       ...       ...
#  31160         0.619578       NaN       NaN
#  31161         0.603079       NaN       NaN
#  31162         0.632082       NaN       NaN
#  31163              NaN  0.509804  0.594771
#  31164              NaN       NaN       NaN
#
#  [31165 rows x 8 columns],
#         epoch   step  train_acc_epoch  train_acc_step  train_loss_epoch  \
#  0          0      0              NaN        0.000000               NaN
#  1          0      1              NaN        0.000000               NaN
#  2          0      2              NaN        0.000000               NaN
#  3          0      3              NaN        0.000000               NaN
#  4          0      4              NaN        0.000000               NaN
#  ...      ...    ...              ...             ...               ...
#  20534    892  18750              NaN        0.700000               NaN
#  20535    892  18751              NaN        0.600000               NaN
#  20536    892  18752              NaN        0.333333               NaN
#  20537    892  18752              NaN             NaN               NaN
#  20538    892  18752         0.514563             NaN          0.475798
#
#         train_loss_step   val_acc  val_loss
#  0             0.390544       NaN       NaN
#  1             0.499968       NaN       NaN
#  2             0.530900       NaN       NaN
#  3             0.397955       NaN       NaN
#  4             0.566592       NaN       NaN
#  ...                ...       ...       ...
#  20534         0.523102       NaN       NaN
#  20535         0.480803       NaN       NaN
#  20536         0.416654       NaN       NaN
#  20537              NaN  0.333333   0.60082
#  20538              NaN       NaN       NaN
#
#  [20539 rows x 8 columns],
#         epoch   step  train_acc_epoch  train_acc_step  train_loss_epoch  \
#  0          0      0              NaN        0.000000               NaN
#  1          0      1              NaN        0.200000               NaN
#  2          0      2              NaN        0.000000               NaN
#  3          0      3              NaN        0.000000               NaN
#  4          0      4              NaN        0.100000               NaN
#  ...      ...    ...              ...             ...               ...
#  12553    545  11463              NaN        0.300000               NaN
#  12554    545  11464              NaN        0.600000               NaN
#  12555    545  11465              NaN        0.666667               NaN
#  12556    545  11465              NaN             NaN               NaN
#  12557    545  11465              0.5             NaN          0.476598
#
#         train_loss_step   val_acc  val_loss
#  0             0.445508       NaN       NaN
#  1             0.658286       NaN       NaN
#  2             0.550741       NaN       NaN
#  3             0.600825       NaN       NaN
#  4             0.462674       NaN       NaN
#  ...                ...       ...       ...
#  12553         0.652532       NaN       NaN
#  12554         0.365416       NaN       NaN
#  12555         0.316098       NaN       NaN
#  12556              NaN  0.294118  0.613237
#  12557              NaN       NaN       NaN
#
#  [12558 rows x 8 columns],
#         epoch  step  train_acc_epoch  train_acc_step  train_loss_epoch  \
#  0          0     0              NaN        0.100000               NaN
#  1          0     1              NaN        0.300000               NaN
#  2          0     2              NaN        0.000000               NaN
#  3          0     3              NaN        0.000000               NaN
#  4          0     4              NaN        0.000000               NaN
#  ...      ...   ...              ...             ...               ...
#  10483    455  9573              NaN        0.700000               NaN
#  10484    455  9574              NaN        0.400000               NaN
#  10485    455  9575              NaN        0.666667               NaN
#  10486    455  9575              NaN             NaN               NaN
#  10487    455  9575          0.57767             NaN          0.457152
#
#         train_loss_step   val_acc  val_loss
#  0             0.347015       NaN       NaN
#  1             0.796297       NaN       NaN
#  2             0.401118       NaN       NaN
#  3             0.793519       NaN       NaN
#  4             0.497478       NaN       NaN
#  ...                ...       ...       ...
#  10483         0.568361       NaN       NaN
#  10484         0.457274       NaN       NaN
#  10485         0.489377       NaN       NaN
#  10486              NaN  0.411765  0.599471
#  10487              NaN       NaN       NaN
#
#  [10488 rows x 8 columns],
#         epoch   step  train_acc_epoch  train_acc_step  train_loss_epoch  \
#  0          0      0              NaN             0.0               NaN
#  1          0      1              NaN             0.0               NaN
#  2          0      2              NaN             0.0               NaN
#  3          0      3              NaN             0.1               NaN
#  4          0      4              NaN             0.0               NaN
#  ...      ...    ...              ...             ...               ...
#  15221    661  13899              NaN             0.4               NaN
#  15222    661  13900              NaN             0.9               NaN
#  15223    661  13901              NaN             0.5               NaN
#  15224    661  13901              NaN             NaN               NaN
#  15225    661  13901         0.669903             NaN           0.45096
#
#         train_loss_step   val_acc  val_loss
#  0             0.390544       NaN       NaN
#  1             0.499963       NaN       NaN
#  2             0.531025       NaN       NaN
#  3             0.397729       NaN       NaN
#  4             0.566797       NaN       NaN
#  ...                ...       ...       ...
#  15221         0.583467       NaN       NaN
#  15222         0.424551       NaN       NaN
#  15223         0.606302       NaN       NaN
#  15224              NaN  0.509804  0.585687
#  15225              NaN       NaN       NaN
#
#  [15226 rows x 8 columns],
#        epoch  step  train_acc_epoch  train_acc_step  train_loss_epoch  \
#  0         0     0              Na
#  12350    536  11276          0.73301             NaN          0.443148
#
#         train_loss_step  val_acc  val_loss
#  0             0.605374      NaN       NaN
#  1             0.426511      NaN       NaN
#  2             0.664643      NaN       NaN
#  3             0.651227      NaN       NaN
#  4             0.345926      NaN       NaN
#  ...                ...      ...       ...
#  12346         0.473588      NaN       NaN
#  12347         0.458689      NaN       NaN
#  12348         0.434364      NaN       NaN
#  12349              NaN  0.45098  0.587504
#  12350              NaN      NaN       NaN
#
#  [12351 rows x 8 columns],
#         epoch  step  train_acc_epoch  train_acc_step  train_loss_epoch  \
#  0          0     0              NaN        0.000000               NaN
#  1          0     1              NaN        0.000000               NaN
#  2          0     2              NaN        0.100000               NaN
#  3          0     3              NaN        0.000000               NaN
#  4          0     4              NaN        0.000000               NaN
#  ...      ...   ...              ...             ...               ...
#  10920    474  9972              NaN        0.900000               NaN
#  10921    474  9973              NaN        0.800000               NaN
#  10922    474  9974              NaN        0.833333               NaN
#  10923    474  9974              NaN             NaN               NaN
#  10924    474  9974         0.684466             NaN           0.44063
#
#         train_loss_step  val_acc  val_loss
#  0             0.425243      NaN       NaN
#  1             0.512128      NaN       NaN
#  2             0.579285      NaN       NaN
#  3             0.473900      NaN       NaN
#  4             0.466312      NaN       NaN
#  ...                ...      ...       ...
#  10920         0.364847      NaN       NaN
#  10921         0.419713      NaN       NaN
#  10922         0.245972      NaN       NaN
#  10923              NaN  0.45098  0.608461
#  10924              NaN      NaN       NaN
#
#  [10925 rows x 8 columns],
#         epoch   step  train_acc_epoch  train_acc_step  train_loss_epoch  \
#  0          0      0              NaN             0.0               NaN
#  1          0      1              NaN             0.0               NaN
#  2          0      2              NaN             0.0               NaN
#  3          0      3              NaN             0.1               NaN
#  4          0      4              NaN             0.0               NaN
#  ...      ...    ...              ...             ...               ...
#  11633    505  10623              NaN             0.8               NaN
#  11634    505  10624              NaN             0.9               NaN
#  11635    505  10625              NaN             1.0               NaN
#  11636    505  10625              NaN             NaN               NaN
#  11637    505  10625         0.830097             NaN          0.424082
#
#         train_loss_step   val_acc  val_loss
#  0             0.642344       NaN       NaN
#  1             0.653077       NaN       NaN
#  2             0.585701       NaN       NaN
#  3             0.588266       NaN       NaN
#  4             0.505978       NaN       NaN
#  ...                ...       ...       ...
#  11633         0.601987       NaN       NaN
#  11634         0.377416       NaN       NaN
#  11635         0.392712       NaN       NaN
#  11636              NaN  0.588235  0.571964
#  11637              NaN       NaN       NaN
#
#  [11638 rows x 8 columns],
#        epoch  step  train_acc_epoch  train_acc_step  train_loss_epoch  \
#  0         0     0              NaN        0.000000               NaN
#  1         0     1              NaN        0.100000               NaN
#  2         0     2              NaN        0.000000               NaN
#  3         0     3              NaN        0.000000               NaN
#  4         0     4              NaN        0.100000               NaN
#  ...     ...   ...              ...             ...               ...
#  8068    350  7368              NaN        0.600000               NaN
#  8069    350  7369              NaN        0.500000               NaN
#  8070    350  7370              NaN        0.666667               NaN
#  8071    350  7370              NaN             NaN               NaN
#  8072    350  7370          0.68932             NaN            0.4476
#
#        train_loss_step   val_acc  val_loss
#  0            0.605374       NaN       NaN
#  1            0.426351       NaN       NaN
#  2            0.664831       NaN       NaN
#  3            0.651439       NaN       NaN
#  4            0.345971       NaN       NaN
#  ...               ...       ...       ...
#  8068         0.269104       NaN       NaN
#  8069         0.547286       NaN       NaN
#  8070         0.301287       NaN       NaN
#  8071              NaN  0.529412  0.602595
#  8072              NaN       NaN       NaN
#
#  [8073 rows x 8 columns],
#        epoch  step  train_acc_epoch  train_acc_step  train_loss_epoch  \
#  0         0     0              NaN             0.0               NaN
#  1         0     1              NaN             0.0               NaN
#  2         0     2              NaN             0.0               NaN
#  3         0     3              NaN             0.0               NaN
#  4         0     4              NaN             0.0               NaN
#  ...     ...   ...              ...             ...               ...
#  7608    330  6948              NaN             0.5               NaN
#  7609    330  6949              NaN             0.9               NaN
#  7610    330  6950              NaN             0.5               NaN
#  7611    330  6950              NaN             NaN               NaN
#  7612    330  6950         0.616505             NaN          0.445223
#
#        train_loss_step   val_acc  val_loss
#  0            0.559749       NaN       NaN
#  1            0.706116       NaN       NaN
#  2            0.650758       NaN       NaN
#  3            0.469657       NaN       NaN
#  4            0.483685       NaN       NaN
#  ...               ...       ...       ...
#  7608         0.471101       NaN       NaN
#  7609         0.359329       NaN       NaN
#  7610         0.350532       NaN       NaN
#  7611              NaN  0.411765  0.607491
#  7612              NaN       NaN       NaN
#
#  [7613 rows x 8 columns],
#        epoch  step  train_acc_epoch  train_acc_step  train_loss_epoch  \
#  0         0     0              NaN        0.000000               NaN
#  1         0     1              NaN        0.000000               NaN
#  2         0     2              NaN        0.100000               NaN
#  3         0     3              NaN        0.000000               NaN
#  4         0     4              NaN        0.100000               NaN
#  ...     ...   ...              ...             ...               ...
#  8551    371  7809              NaN        0.900000               NaN
#  8552    371  7810              NaN        0.700000               NaN
#  8553    371  7811              NaN        0.666667               NaN
#  8554    371  7811              NaN             NaN               NaN
#  8555    371  7811         0.776699             NaN            0.4251
#
#        train_loss_step   val_acc  val_loss
#  0            0.553874       NaN       NaN
#  1            0.641420       NaN       NaN
#  2            0.353938       NaN       NaN
#  3            0.617368       NaN       NaN
#  4            0.420646       NaN       NaN
#  ...               ...       ...       ...
#  8551         0.653760       NaN       NaN
#  8552         0.424401       NaN       NaN
#  8553         0.595622       NaN       NaN
#  8554              NaN  0.509804  0.577084
#  8555              NaN       NaN       NaN
#
#  [8556 rows x 8 columns],
#        epoch  step  train_acc_epoch  train_acc_step  train_loss_epoch  \
#  0         0     0              NaN             0.1               NaN
#  1         0     1              NaN             0.2               NaN
#  2         0     2              NaN             0.1               NaN
#  3         0     3              NaN             0.0               NaN
#  4         0     4              NaN             0.0               NaN
#  ...     ...   ...              ...             ...               ...
#  6297    273  5751              NaN             0.6               NaN
#  6298    273  5752              NaN             0.8               NaN
#  6299    273  5753              NaN             1.0               NaN
#  6300    273  5753              NaN             NaN               NaN
#  6301    273  5753         0.752427             NaN          0.432577
#
#        train_loss_step   val_acc  val_loss
#  0            0.594570       NaN       NaN
#  1            0.481129       NaN       NaN
#  2            0.566571       NaN       NaN
#  3            0.500070       NaN       NaN
#  4            0.604850       NaN       NaN
#  ...               ...       ...       ...
#  6297         0.476845       NaN       NaN
#  6298         0.378276       NaN       NaN
#  6299         0.508502       NaN       NaN
#  6300              NaN  0.470588  0.607115
#  6301              NaN       NaN       NaN
#
#  [6302 rows x 8 columns],
#        epoch  step  train_acc_epoch  train_acc_step  train_loss_epoch  \
#  0         0     0              NaN        0.000000               NaN
#  1         0     1              NaN        0.200000               NaN
#  2         0     2              NaN        0.000000               NaN
#  3         0     3              NaN        0.000000               NaN
#  4         0     4              NaN        0.000000               NaN
#  ...     ...   ...              ...             ...               ...
#  9402    408  8586              NaN        0.600000               NaN
#  9403    408  8587              NaN        0.800000               NaN
#  9404    408  8588              NaN        0.666667               NaN
#  9405    408  8588              NaN             NaN               NaN
#  9406    408  8588         0.699029             NaN          0.448433
#
#        train_loss_step   val_acc  val_loss
#  0            0.559749       NaN       NaN
#  1            0.705914       NaN       NaN
#  2            0.650604       NaN       NaN
#  3            0.469913       NaN       NaN
#  4            0.484124       NaN       NaN
#  ...               ...       ...       ...
#  9402         0.827256       NaN       NaN
#  9403         0.473618       NaN       NaN
#  9404         0.362249       NaN       NaN
#  9405              NaN  0.235294  0.640463
#  9406              NaN       NaN       NaN
#
#  [9407 rows x 8 columns],
#         epoch   step  train_acc_epoch  train_acc_step  train_loss_epoch  \
#  0          0      0              NaN        0
rows x 8 columns],
#         epoch   step  train_acc_epoch  train_acc_step  train_loss_epoch  \
#  0          0      0              NaN        0.000000               NaN
#  1          0      1              NaN        0.100000               NaN
#  2          0      2              NaN        0.000000               NaN
#  3          0      3              NaN        0.000000               NaN
#  4          0      4              NaN        0.000000               NaN
#  ...      ...    ...              ...             ...               ...
#  20649    897  18855              NaN        0.700000               NaN
#  20650    897  18856              NaN        0.700000               NaN
#  20651    897  18857              NaN        0.666667               NaN
#  20652    897  18857              NaN             NaN               NaN
#  20653    897  18857          0.68932             NaN          0.445064
#
#         train_loss_step   val_acc  val_loss
#  0             0.425271       NaN       NaN
#  1             0.512249       NaN       NaN
#  2             0.579239       NaN       NaN
#  3             0.474045       NaN       NaN
#  4             0.466256       NaN       NaN
#  ...                ...       ...       ...
#  20649         0.394114       NaN       NaN
#  20650         0.602436       NaN       NaN
#  20651         0.414314       NaN       NaN
#  20652              NaN  0.588235  0.569424
#  20653              NaN       NaN       NaN
#
#  [20654 rows x 8 columns],
#         epoch   step  train_acc_epoch  train_acc_step  train_loss_epoch  \
#  0          0      0              NaN        0.000000               NaN
#  1          0      1              NaN        0.000000               NaN
#  2          0      2              NaN        0.000000               NaN
#  3          0      3              NaN        0.000000               NaN
#  4          0      4              NaN        0.000000               NaN
#  ...      ...    ...              ...             ...               ...
#  12231    531  11169              NaN        0.500000               NaN
#  12232    531  11170              NaN        0.600000               NaN
#  12233    531  11171              NaN        0.166667               NaN
#  12234    531  11171              NaN             NaN               NaN
#  12235    531  11171         0.538835             NaN          0.466152
#
#         train_loss_step  val_acc  val_loss
#  0             0.642516      NaN       NaN
#  1             0.652761      NaN       NaN
#  2             0.586030      NaN       NaN
#  3             0.588249      NaN       NaN
#  4             0.506079      NaN       NaN
#  ...                ...      ...       ...
#  12231         0.467504      NaN       NaN
#  12232         0.408740      NaN       NaN
#  12233         0.406695      NaN       NaN
#  12234              NaN  0.45098  0.585366
#  12235              NaN      NaN       NaN
#
#  [12236 rows x 8 columns],
#         epoch   step  train_acc_epoch  train_acc_step  train_loss_epoch  \
#  0          0      0              NaN        0.000000               NaN
#  1          0      1              NaN        0.000000               NaN
#  2          0      2              NaN        0.000000               NaN
#  3          0      3              NaN        0.000000               NaN
#  4          0      4              NaN        0.100000               NaN
#  ...      ...    ...              ...             ...               ...
#  17498    760  15978              NaN        0.500000               NaN
#  17499    760  15979              NaN        0.900000               NaN
#  17500    760  15980              NaN        0.666667               NaN
#  17501    760  15980              NaN             NaN               NaN
#  17502    760  15980          0.73301             NaN          0.441457
#
#         train_loss_step   val_acc  val_loss
#  0             0.605201       NaN       NaN
#  1             0.426541       NaN       NaN
#  2             0.664493       NaN       NaN
#  3             0.650673       NaN       NaN
#  4             0.345704       NaN       NaN
#  ...                ...       ...       ...
#  17498         0.481747       NaN       NaN
#  17499         0.478675       NaN       NaN
#  17500         0.538097       NaN       NaN
#  17501              NaN  0.588235  0.573939
#  17502              NaN       NaN       NaN
#
#  [17503 rows x 8 columns],
#         epoch  step  train_acc_epoch  train_acc_step  train_loss_epoch  \
#  0          0     0              NaN        0.000000               NaN
#  1          0     1              NaN        0.000000               NaN
#  2          0     2              NaN        0.000000               NaN
#  3          0     3              NaN        0.000000               NaN
#  4          0     4              NaN        0.000000               NaN
#  ...      ...   ...              ...             ...               ...
#  10506    456  9594              NaN        0.800000               NaN
#  10507    456  9595              NaN        0.600000               NaN
#  10508    456  9596              NaN        0.833333               NaN
#  10509    456  9596              NaN             NaN               NaN
#  10510    456  9596         0.713592             NaN          0.445911
#
#         train_loss_step   val_acc  val_loss
#  0             0.425271       NaN       NaN
#  1             0.512318       NaN       NaN
#  2             0.579480       NaN       NaN
#  3             0.474396       NaN       NaN
#  4             0.466305       NaN       NaN
#  ...                ...       ...       ...
#  10506         0.293143       NaN       NaN
#  10507         0.547024       NaN       NaN
#  10508         0.394840       NaN       NaN
#  10509              NaN  0.352941  0.621347
#  10510              NaN       NaN       NaN
#
#  [10511 rows x 8 columns],
#        epoch  step  train_acc_epoch  train_acc_step  train_loss_epoch  \
#  0         0     0              NaN        0.000000               NaN
#  1         0     1              NaN        0.000000               NaN
#  2         0     2              NaN        0.000000               NaN
#  3         0     3              NaN        0.000000               NaN
#  4         0     4              NaN        0.000000               NaN
#  ...     ...   ...              ...             ...               ...
#  9080    394  8292              NaN        0.700000               NaN
#  9081    394  8293              NaN        0.600000               NaN
#  9082    394  8294              NaN        0.666667               NaN
#  9083    394  8294              NaN             NaN               NaN
#  9084    394  8294         0.640777             NaN          0.450526
#
#        train_loss_step   val_acc  val_loss
#  0            0.642516       NaN       NaN
#  1            0.652715       NaN       NaN
#  2            0.585858       NaN       NaN
#  3            0.588542       NaN       NaN
#  4            0.506134       NaN       NaN
#  ...               ...       ...       ...
#  9080         0.497149       NaN       NaN
#  9081         0.743342       NaN       NaN
#  9082         0.716737       NaN       NaN
#  9083              NaN  0.607843  0.581103
#  9084              NaN       NaN       NaN
#
#  [9085 rows x 8 columns],
#        epoch  step  train_acc_epoch  train_acc_step  train_loss_epoch  \
#  0         0     0              NaN        0.000000               NaN
#  1         0     1              NaN        0.100000               NaN
#  2         0     2              NaN        0.000000               NaN
#  3         0     3              NaN        0.000000               NaN
#  4         0     4              NaN        0.100000               NaN
#  ...     ...   ...              ...             ...               ...
#  6182    268  5646              NaN        0.500000               NaN
#  6183    268  5647              NaN        0.200000               NaN
#  6184    268  5648              NaN        0.166667               NaN
#  6185    268  5648              NaN             NaN               NaN
#  6186    268  5648         0.291262             NaN          0.506765
#
#        train_loss_step   val_acc  val_loss
#  0            0.605201       NaN       NaN
#  1            0.425300       NaN       NaN
#  2            0.664949       NaN       NaN
#  3            0.651474       NaN       NaN
#  4            0.343302       NaN       NaN
#  ...               ...       ...       ...
#  6182         0.468734       NaN       NaN
#  6183         0.323688       NaN       NaN
#  6184         0.507526       NaN       NaN
#  6185              NaN  0.196078  0.638181
#  6186              NaN       NaN       NaN
#
#  [6187 rows x 8 columns],
#         epoch   step  train_acc_epoch  train_acc_step  train_loss_epoch  \
#  0          0      0              NaN        0.000000               NaN
#  1          0      1              NaN        0.000000               NaN
#  2          0      2              NaN        0.000000               NaN
#  3          0      3              NaN        0.000000               NaN
#  4          0      4              NaN        0.000000               NaN
#  ...      ...    ...              ...             ...               ...
#  20511    891  18729              NaN        0.900000               NaN
#  20512    891  18730              NaN        0.800000               NaN
#  20513    891  18731              NaN        0.666667               NaN
#  20514    891  18731              NaN             NaN               NaN
#  20515    891  18731         0.757282             NaN          0.428305
#
#         train_loss_step   val_acc  val_loss
#  0             0.559819       NaN       NaN
#  1             0.706227       NaN       NaN
#  2             0.650868       NaN       NaN
#  3             0.469774       NaN       NaN
#  4             0.483610       NaN       NaN
#  ...                ...       ...       ...
#  20511         0.439277       NaN       NaN
#  20512         0.537104       NaN       NaN
#  20513         0.278609       NaN       NaN
#  20514              NaN  0.647059  0.561122
#  20515              NaN       NaN       NaN
#
#  [20516 rows x 8 columns],
#         epoch   step  train_acc_epoch  train_acc_step  train_loss_epoch  \
#  0          0      0              NaN             0.0               NaN
#  1          0      1              NaN             0.0               NaN
#  2          0      2              NaN             0.1               NaN
#  3          0      3              NaN             0.1               NaN
#  4          0      4              NaN             0.1               NaN
#  ...      ...    ...              ...             ...               ...
#  15474    672  14130              NaN             0.8               NaN
#  15475    672  14131              NaN             0.7               NaN
#  15476    672  14132              NaN             0.5               NaN
#  15477    672  14132              NaN             NaN               NaN
#  15478    672  14132         0.776699             NaN          0.433252
#
#         train_loss_step   val_acc  val_loss
#  0             0.553970       NaN       NaN
#  1             0.641535       NaN       NaN
#  2             0.353827       NaN       NaN
#  3             0.617438       NaN       NaN
#  4             0.420612       NaN       NaN
#  ...                ...       ...       ...
#  15474         0.350166       NaN       NaN
#  15475         0.351739       NaN       NaN
#  15476         0.453218       NaN       NaN
#  15477              NaN  0.686275   0.57292
#  15478              NaN       NaN       NaN
#
#  [15479 rows x 8 columns],
#        epoch  step  train_acc_epoch  train_acc_step  train_loss_epoch  \
#  0         0     0              NaN        0.100000               NaN
#  1         0     1              NaN        0.100000               NaN
#  2         0     2              NaN        0.100000               NaN
#  3         0     3              NaN        0.000000               NaN
#  4         0     4              NaN        0.000000               NaN
#  ...     ...   ...              ...             ...               ...
#  6826    296  6234              NaN        0.500000               NaN
#  6827    296  6235              NaN        0.800000               NaN
#  6828    296  6236              NaN        0.833333               NaN
#  6829    296  6236              NaN             NaN               NaN
#  6830    296  6236         0.606796             NaN          0.459468
#
#        train_loss_step   val_acc  val_loss
#  0            0.594491       NaN       NaN
#  1            0.481193       NaN       NaN
#  2            0.566485       NaN       NaN
#  3            0.500176       NaN       NaN
#  4            0.604985       NaN       NaN
#  ...               ...       ...       ...
#  6826         0.312662       NaN       NaN
#  6827         0.368094       NaN       NaN
#  6828         0.274264       NaN       NaN
#  6829              NaN  0.392157  0.596621
#  6830              NaN       NaN       NaN
#
#  [6831 rows x 8 columns],
#         epoch   step  train_acc_epoch  train_acc_step  train_loss_epoch  \
#  0          0      0              NaN             0.0               NaN
#  1          0      1              NaN             0.1               NaN
#  2          0      2              NaN             0.1               NaN
#  3          0      3              NaN             0.0               NaN
#  4          0      4              NaN             0.0               NaN
#  ...      ...    ...              ...             ...               ...
#  12944    562  11820              NaN             0.5               NaN
#  12945    562  11821              NaN             0.7               NaN
#  12946    562  11822              NaN             0.5               NaN
#  12947    562  11822              NaN             NaN               NaN
#  12948    562  11822          0.57767             NaN          0.451579
#
#         train_loss_step   val_acc  val_loss
#  0             0.559819       NaN       NaN
#  1             0.705814       NaN       NaN
#  2             0.650646       NaN       NaN
#  3             0.469979       NaN       NaN
#  4             0.483990       NaN       NaN
#  ...                ...       ...       ...
#  12944         0.396128       NaN       NaN
#  12945         0.369877       NaN       NaN
#  12946         0.382115       NaN       NaN
#  12947              NaN  0.470588  0.588376
#  12948              NaN       NaN       NaN
#
#  [12949 rows x 8 columns],
#        epoch  step  train_acc_epoch  train_acc_step  train_loss_epoch  \
#  0         0     0              NaN        0.000000               NaN
#  1         0     1              NaN        0.000000               NaN
#  2         0     2              NaN        0.100000               NaN
#  3         0     3              NaN        0.000000               NaN
#  4         0     4              NaN        0.000000               NaN
#  ...     ...   ...              ...             ...               ...
#  6688    290  6108              NaN        0.300000               NaN
#  6689    290  6109              NaN        0.300000               NaN
#  6690    290  6110              NaN        0.666667               NaN
#  6691    290  6110              NaN             NaN               NaN
#  6692    290  6110         0.330097             NaN          0.504219
#
#        train_loss_step   val_acc  val_loss
#  0            0.553970       NaN       NaN
#  1            0.641598       NaN       NaN
#  2            0.353860       NaN       NaN
#  3            0.617540       NaN       NaN
#  4            0.420765       NaN       NaN
#  ...               ...       ...       ...
#  6688         0.402884       NaN       NaN
#  6689         0.435808       NaN       NaN
#  6690         0.358429       NaN       NaN
#  6691              NaN  0.333333  0.627166
#  6692              NaN       NaN       NaN
#
#  [6693 rows x 8 columns],
#        epoch  step  train_acc_epoch  train_acc_step  train_loss_epoch  \
#  0         0     0              NaN             0.1               NaN
#  1         0     1              NaN             0.0               NaN
#  2         0     2              NaN             0.0               NaN
#  3         0     3              NaN             0.0               NaN
#  4         0     4              NaN             0.1               NaN
#  ...     ...   ...              ...             ...               ...
#  3353    145  3063              NaN             0.4               NaN
#  3354    145  3064              NaN             0.1               NaN
#  3355    145  3065              NaN             0.0               NaN
#  3356    145  3065              NaN             NaN               NaN
#  3357    145  3065         0.135922             NaN          0.528236
#
#        train_loss_step   val_acc  val_loss
#  0            0.594491       NaN       NaN
#  1            0.481485       NaN       NaN
#  2            0.567105       NaN       NaN
#  3            0.500383       NaN       NaN
#  4            0.604766       NaN       NaN
#  ...               ...       ...       ...
#  3353         0.351640       NaN       NaN
#  3354         0.306695       NaN       NaN
#  3355         0.543432       NaN       NaN
#  3356              NaN  0.098039  0.651137
#  3357              NaN       NaN       NaN
#
#  [3358 rows x 8 columns]]

# %%
run_eval.get_keys('metrics')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 run_eval.get_keys('metrics')
#
# Cell In[65], line 111, in RunEval.get_keys(self, data_type)
#     106 def get_keys(self, data_type: str):
#     107     """
#     108     Datatype: Options are: ["metrics", "predictions", "model_info"]
#     109     """
# --> 111     data = self.get_model_data(data_type)
#     112     keys = data[0].keys()
#     114     return keys
#
# Cell In[65], line 80, in RunEval.get_model_data(self, data_type, eval_subset)
#      78 for model_path in self.model_paths:
#      79     new_data = model_data(model_path)
# ---> 80     new_row = pd.DataFrame([new_data])
#      82     data = pd.concat([data, new_row], ignore_index=True)
#      84 return data
#
# File c:\Users\kraft\.conda\envs\torch_cuda\Lib\site-packages\pandas\core\frame.py:856, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     848         mgr = arrays_to_mgr(
#     849             arrays,
#     850             columns,
#    (...)
#     853             typ=manager,
#     854         )
#     855     else:
# --> 856         mgr = ndarray_to_mgr(
#     857             data,
#     858             index,
#     859             columns,
#     860             dtype=dtype,
#     861             copy=copy,
#     862             typ=manager,
#     863         )
#     864 else:
#     865     mgr = dict_to_mgr(
#     866         {},
#     867         index,
#    (...)
#     870         typ=manager,
#     871     )
#
# File c:\Users\kraft\.conda\envs\torch_cuda\Lib\site-packages\pandas\core\internals\construction.py:319, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     314     values = _ensure_2d(values)
#     316 else:
#     317     # by definition an array here
#     318     # the dtypes will be coerced to a single dtype
# --> 319     values = _prep_ndarraylike(values, copy=copy_on_sanitize)
#     321 if dtype is not None and values.dtype != dtype:
#     322     # GH#40110 see similar check inside sanitize_array
#     323     values = sanitize_array(
#     324         values,
#     325         None,
#    (...)
#     328         allow_2d=True,
#     329     )
#
# File c:\Users\kraft\.conda\envs\torch_cuda\Lib\site-packages\pandas\core\internals\construction.py:582, in _prep_ndarraylike(values, copy)
#     579 else:
#     580     values = convert(values)
# --> 582 return _ensure_2d(values)
#
# File c:\Users\kraft\.conda\envs\torch_cuda\Lib\site-packages\pandas\core\internals\construction.py:592, in _ensure_2d(values)
#     590     values = values.reshape((values.shape[0], 1))
#     591 elif values.ndim != 2:
# --> 592     raise ValueError(f"Must pass 2-d input. shape={values.shape}")
#     593 return values
#
# ValueError: Must pass 2-d input. shape=(1, 31165, 8)
